# %% [markdown]
# ### Live DS interview for pod

# %%
# Out:
# /var/folders/cf/zk37hd_50bv_nlrdlxrb4q3r0000gn/T/ipykernel_3652/1747978850.py:69: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   month_ends = pd.date_range(dates.min(), dates.max(), freq="BM")
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 95
#      93 for t in rng.choice(tickers, size=20, replace=False):
#      94     eff = rng.choice(dates[30:-30])
# ---> 95     ann = pd.bdate_range(eff, periods=-rng.integers(1, 8), freq="B")[-1]  # 1-7 biz days before effective
#      96     action = rng.choice(["ADD","DROP"])
#      97     events.append((t, ann, eff, action))
#
# File ~/opt/miniconda3/envs/fingers_crossed/lib/python3.11/site-packages/pandas/core/indexes/base.py:5389, in Index.__getitem__(self, key)
#    5386 if is_integer(key) or is_float(key):
# ...
